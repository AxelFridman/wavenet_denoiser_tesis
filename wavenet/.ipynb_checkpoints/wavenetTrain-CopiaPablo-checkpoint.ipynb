# %%
import torch
import torch.nn as nn
import torchaudio
import torch.fft
from torch.utils.data import Dataset
from torch.utils.data import DataLoader
import matplotlib.pyplot as plt
import numpy as np
from IPython.display import Audio
import seaborn as sns
import pandas as pd
import os
from torch.nn.utils.rnn import pad_sequence
import torchvision.transforms as transforms
import torchaudio.transforms as transformsaudio
import datetime
from torch.utils.tensorboard import SummaryWriter
import soundfile as sf
import time
import torch.nn.functional as F
import math
import random
import pytorch_lightning as pl
from pytorch_lightning.callbacks.early_stopping import EarlyStopping

writer = SummaryWriter()
# %load_ext tensorboard

from prettytable import PrettyTable

def count_parameters(model):
    table = PrettyTable(["Modules", "Parameters"])
    total_params = 0
    for name, parameter in model.named_parameters():
        if not parameter.requires_grad:
            continue
        params = parameter.numel()
        table.add_row([name, params])
        total_params += params
    print(table)
    print(f"Total Trainable Params: {total_params}")
    return total_params

import sys
def size_of_tensor(a):
    return sys.getsizeof(a) + torch.numel(a)*a.element_size()
# Out:
# The tensorboard extension is already loaded. To reload it, use:
#   %reload_ext tensorboard

# %%
directoryBase = os.getcwd()

# %%
directoryBase
# Out:
# '/home/afridman/tesisPabloAxel/wavenet'

# %%
#import zipfile
#with zipfile.ZipFile('modelos.zip', 'r') as zip_ref:
#    zip_ref.extractall('')

# %%
def pad_to_max_length(tensor1, tensor2):
    max_length = max(tensor1.size(1), tensor2.size(1))

    pad_tensor1 = torch.nn.functional.pad(tensor1, (0, max_length - tensor1.size(1)))
    pad_tensor2 = torch.nn.functional.pad(tensor2, (0, max_length - tensor2.size(1)))

    return pad_tensor1, pad_tensor2

# %%
inputSize = 32000
class AudioCleaningDataset(Dataset):
    def __init__(self, csv_file, audio_dir, noise_dir, reverb_dir, target_length=inputSize, device='cpu'):
        self.dataframe = pd.read_csv(csv_file)
        self.audio_dir = audio_dir
        self.noise_dir = noise_dir
        self.reverb_dir = reverb_dir
        self.target_length = target_length
        self.resampleo = transformsaudio.Resample(orig_freq=48000, new_freq=16000)  # Resampling
        self.resampleoIR = transformsaudio.Resample(orig_freq=32000, new_freq=16000)  # Resampling

        self.noise_files = os.listdir(noise_dir) # List all noise files
        self.reverb_files = os.listdir(reverb_dir)
        self.device = device
        self.conv= transformsaudio.Convolve(mode="same")


    def __len__(self):
        return len(self.dataframe)

    def __getitem__(self, idx):
        if torch.is_tensor(idx):
            idx = idx.tolist()

        audio_file_name = os.path.join(self.audio_dir, self.dataframe.iloc[idx]['audio_file_name']+".wav")
        waveform, sample_rate = torchaudio.load(audio_file_name)

        waveformOriginal = self.resampleo(waveform)

        #aca seleccionar
        maximoPosible = len(waveformOriginal[0])-self.target_length
        if(maximoPosible>1):
          comienzoAleatorio = (random.randint(0,maximoPosible))
          waveformOriginal = waveformOriginal[:,comienzoAleatorio:comienzoAleatorio+self.target_length]
        #print(len(waveformOriginal[0]))


        waveformSucia = waveformOriginal.clone()
        padding = torch.zeros((1, max(self.target_length - waveformSucia.size(1),1)))

        waveformOriginal = torch.cat((waveformOriginal, padding), dim=1)
        waveformSucia = torch.cat((waveformSucia, padding), dim=1)

        waveformOriginal = waveformOriginal[:,:self.target_length].to(self.device)
        waveformSucia = waveformSucia[:,:self.target_length].to(self.device)

        return 1*waveformSucia, 1*waveformOriginal
    
#         # Load a random noise file
#         noise_file_name = random.choice(self.noise_files)
#         noise_waveform, sample_Rate_ruido = torchaudio.load(os.path.join(self.noise_dir, noise_file_name))
#         # Repeat the noise waveform until it's at least as long as the audio waveform
#         while noise_waveform.size(1) < waveformSucia.size(1):
#             noise_waveform = torch.cat((noise_waveform, noise_waveform), dim=1)

#         # Trim the noise waveform to match the length of the audio waveform
#         noise_waveform = noise_waveform[:,:waveformSucia.size(1)]

#         # Add noise with a random signal-to-noise ratio between 0.01 and 0.1
#         snr = random.uniform(0.001, 0.01) #random.uniform(0.01, 0.1)

#         # LE SACO EL RUIDO SUCIO PARA ACELERAR APRENDIZAJE !!!!!!!!!!!!!!!!!!!!!!!!!!!!
#         #waveformSucia = waveformSucia + noise_waveform * snr
#         whitenoise = random.uniform(0.0001, 0.001)
#         #waveformSucia = waveformSucia + torch.randn_like(waveformOriginal) * whitenoise


#         IR_file_name = random.choice(self.reverb_files)
#         IR_waveform, sample_Rate_IR = torchaudio.load(os.path.join(self.reverb_dir, IR_file_name))
#         IR_waveform = self.resampleoIR(IR_waveform)

#         # Normalize impulse response
#         normalized_ir = IR_waveform / (IR_waveform.abs().max())

#         # Perform convolution
#         padded_signal, padded_filter = pad_to_max_length(waveformSucia, normalized_ir)

#         # Perform the FFT
#         fft_signal = torch.fft.fft(padded_signal)
#         fft_filter = torch.fft.fft(padded_filter)

#         # Perform the convolution in the frequency domain
#         fft_result = fft_signal * fft_filter

#         # Perform the inverse FFT to get the result in the time domain
#         result = torch.fft.ifft(fft_result)

#         # The result is complex, take the real part

#         # LE SACO EL REVERB PARA ACELERAR APRENDIZAJE !!!!!!!!!!!!!!!!!!!!!!!!!!!!
#         #waveformSucia = result.real

#         padding = torch.zeros((1, max(self.target_length - waveformSucia.size(1),1)))

#         waveformOriginal = torch.cat((waveformOriginal, padding), dim=1)
#         waveformSucia = torch.cat((waveformSucia, padding), dim=1)

#         waveformOriginal = waveformOriginal[:,:self.target_length].to(self.device)
#         waveformSucia = waveformSucia[:,:self.target_length].to(self.device)

#        # waveformOriginal = (waveformOriginal - waveformOriginal.mean()) / waveformOriginal.std()
#        # waveformSucia = (waveformSucia - waveformSucia.mean()) / waveformSucia.std()
#        # Optional: Normalize convolved audio
#        # waveformSucia = waveformSucia / (waveformSucia.abs().max())
#        # waveformOriginal = waveformOriginal / (waveformOriginal.abs().max())

#         return 1*waveformSucia, 1*waveformOriginal

# %%
"""
Neural network modules for WaveNet

References :
    https://arxiv.org/pdf/1609.03499.pdf
    https://github.com/ibab/tensorflow-wavenet
    https://qiita.com/MasaEguchi/items/cd5f7e9735a120f27e2a
    https://github.com/musyoku/wavenet/issues/4
"""

class DilatedCausalConv1d(torch.nn.Module):
    """Dilated Causal Convolution for WaveNet"""
    def __init__(self, channels, dilation=1, device='cpu'):
        super(DilatedCausalConv1d, self).__init__()

        self.conv = torch.nn.Conv1d(channels, channels,
                                    kernel_size=2, stride=1,  # Fixed for WaveNet
                                    dilation=dilation,
                                    padding=dilation,  # Fixed for WaveNet dilation
                                    bias=False)  # Fixed for WaveNet but not sure
    
        self.conv = self.conv.to(device)

    def init_weights_for_test(self):
        for m in self.modules():
            if isinstance(m, torch.nn.Conv1d):
                m.weight.data.fill_(1)

    def forward(self, x):
        output = self.conv(x)

        return output


class CausalConv1d(torch.nn.Module):
    """Causal Convolution for WaveNet"""
    def __init__(self, in_channels, out_channels, device='cpu'):
        super(CausalConv1d, self).__init__()

        # padding=1 for same size(length) between input and output for causal convolution
        self.conv = torch.nn.Conv1d(in_channels, out_channels,
                                    kernel_size=2, stride=1, padding=1,
                                    bias=False)  # Fixed for WaveNet but not sure
        if torch.cuda.is_available():
            self.conv = self.conv.to(device)

    def init_weights_for_test(self):
        for m in self.modules():
            if isinstance(m, torch.nn.Conv1d):
                m.weight.data.fill_(1)

    def forward(self, x):
        output = self.conv(x)

        # remove last value for causal convolution
        return output[:, :, :-1]


class ResidualBlock(torch.nn.Module):
    def __init__(self, res_channels, skip_channels, dilation, device='cpu'):
        """
        Residual block
        :param res_channels: number of residual channel for input, output
        :param skip_channels: number of skip channel for output
        :param dilation:
        """
        super(ResidualBlock, self).__init__()

        self.dilated = DilatedCausalConv1d(res_channels, dilation=dilation)
        self.conv_res = torch.nn.Conv1d(res_channels, res_channels, 1)
        self.conv_skip = torch.nn.Conv1d(res_channels, skip_channels, 1)

        self.gate_tanh = torch.nn.Tanh()
        self.gate_sigmoid = torch.nn.Sigmoid()

        self.conv_skip = self.conv_skip.to(device)
        self.conv_res = self.conv_res.to(device)

    def forward(self, x, skip_size):
        """
        :param x:
        :param skip_size: The last output size for loss and prediction
        :return:
        """
        output = self.dilated(x)

        # PixelCNN gate
        gated_tanh = self.gate_tanh(output)
        gated_sigmoid = self.gate_sigmoid(output)
        gated = gated_tanh * gated_sigmoid

        # Residual network
        output = self.conv_res(gated)
        output = output[:, :, 0:inputSize]

        input_cut = x#[:, :, -output.size(2):]

        output += input_cut

        # Skip connection
        skip = self.conv_skip(gated)
        skip = skip[:, :, -skip_size:]

        return output, skip


class ResidualStack(torch.nn.Module):
    def __init__(self, layer_size, stack_size, res_channels, skip_channels, device='cpu'):
        """
        Stack residual blocks by layer and stack size
        :param layer_size: integer, 10 = layer[dilation=1, dilation=2, 4, 8, 16, 32, 64, 128, 256, 512]
        :param stack_size: integer, 5 = stack[layer1, layer2, layer3, layer4, layer5]
        :param res_channels: number of residual channel for input, output
        :param skip_channels: number of skip channel for output
        :return:
        """
        super(ResidualStack, self).__init__()

        self.layer_size = layer_size
        self.stack_size = stack_size

        self.device = device
        self.res_blocks = self.stack_res_block(res_channels, skip_channels)

    @staticmethod
    def _residual_block(res_channels, skip_channels, dilation, device='cpu'):
        block = ResidualBlock(res_channels, skip_channels, dilation)

        if torch.cuda.device_count() > 1:
            block = torch.nn.DataParallel(block)

        
        block.to(device)

        return block

    def build_dilations(self):
        dilations = []

        # 5 = stack[layer1, layer2, layer3, layer4, layer5]
        for s in range(0, self.stack_size):
            # 10 = layer[dilation=1, dilation=2, 4, 8, 16, 32, 64, 128, 256, 512]
            for l in range(0, self.layer_size):
                dilations.append(2 ** l)

        return dilations

    def stack_res_block(self, res_channels, skip_channels):
        """
        Prepare dilated convolution blocks by layer and stack size
        :return:
        """
        res_blocks = []
        dilations = self.build_dilations()

        for dilation in dilations:
            block = self._residual_block(res_channels, skip_channels, dilation)
            res_blocks.append(block)

        return res_blocks

    def forward(self, x, skip_size):
        """
        :param x:
        :param skip_size: The last output size for loss and prediction
        :return:
        """
        output = x
        skip_connections = []

        for res_block in self.res_blocks:
            # output is the next input
            output, skip = res_block(output, skip_size)

            skip_connections.append(skip)


        return torch.stack(skip_connections)


class DensNet(torch.nn.Module):
    def __init__(self, channels, device='cpu'):
        """
        The last network of WaveNet
        :param channels: number of channels for input and output
        :return:
        """
        super(DensNet, self).__init__()

        self.conv1 = torch.nn.Conv1d(channels, channels, kernel_size=3, stride=1, padding=1)
        self.conv2 = torch.nn.Conv1d(channels, channels, kernel_size=3, stride=1, padding=1)

        self.tan = torch.nn.Tanh()

        self.conv1 = self.conv1.to(device)
        self.conv2 = self.conv2.to(device)

    def forward(self, x):
        output = self.conv1(x)
        output = self.tan(output)
        output = self.conv2(output)

        return output

# %%
class WaveNet(pl.LightningModule):
    def __init__(self, layer_size, stack_size, in_channels, res_channels):
        """
        Stack residual blocks by layer and stack size
        :param layer_size: integer, 10 = layer[dilation=1, dilation=2, 4, 8, 16, 32, 64, 128, 256, 512]
        :param stack_size: integer, 5 = stack[layer1, layer2, layer3, layer4, layer5]
        :param in_channels: number of channels for input data. skip channel is same as input channel
        :param res_channels: number of residual channel for input, output
        :return:
        """
        super(WaveNet, self).__init__()

        self.receptive_fields = self.calc_receptive_fields(layer_size, stack_size)

        self.causal = CausalConv1d(in_channels, res_channels)

        self.res_stack = ResidualStack(layer_size, stack_size, res_channels, in_channels)

        self.densnet = DensNet(in_channels)

        self.loss_fun = nn.MSELoss()


    @staticmethod
    def calc_receptive_fields(layer_size, stack_size):
        layers = [2 ** i for i in range(0, layer_size)] * stack_size
        num_receptive_fields = np.sum(layers)

        return int(num_receptive_fields)

    def calc_output_size(self, x):
        output_size = int(x.size(2)) - self.receptive_fields

        #self.check_input_size(x, output_size)

        return inputSize

    def check_input_size(self, x, output_size):
        if output_size < 1:
            raise InputSizeError(int(x.size(2)), self.receptive_fields, output_size)

    def forward(self, x):
        """
        The size of timestep(3rd dimention) has to be bigger than receptive fields
        :param x: Tensor[batch, timestep, channels]
        :return: Tensor[batch, timestep, channels]
        """
        output = x#.transpose(1, 2)

        output_size = self.calc_output_size(output)

        output = self.causal(output)

        skip_connections = self.res_stack(output, output_size)


        #en vez de sumar skip connections hago convolucion
        #print(skip_connections.shape)
        output = torch.sum(skip_connections, dim=0)


        output = self.densnet(output)

        return output#.transpose(1, 2).contiguous()

# %%
modeloNombre = directoryBase+'/modelos/wavenetReal/wavenetReplicaAudio.pth'

# %%
#del wavenetModel
#del dataloader
#del waveform
#torch.cuda.empty_cache()

# %%
dataset = AudioCleaningDataset(directoryBase+'/CSV/audio_pocos.csv', directoryBase+'/audiosDivididos/', directoryBase+'/audiosDivididos/ruidosPocos/', directoryBase+"/audiosDivididos/reverbPocos")
dataloader = DataLoader(dataset, batch_size=3, shuffle=True)

# %%
waveform, label = next(iter(dataloader))

# %%
Audio(data=waveform.cpu()[0], rate=16000)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
Audio(data=label.cpu()[0], rate=16000)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
#dict(wavenetModel.named_parameters()).keys()

# %%
wavenetModel = WaveNet( layer_size=18, stack_size=2, in_channels=1, res_channels=128)

# wavenetModel = torch.load(modeloNombre, map_location=torch.device('cuda'))
wavenetModel = wavenetModel.to('cpu')
#.load_state_dict(torch.load(modeloNombre))
count_parameters(wavenetModel)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[40], line 1
# ----> 1 wavenetModel = WaveNet( layer_size=18, stack_size=2, in_channels=1, res_channels=128)
#       3 # wavenetModel = torch.load(modeloNombre, map_location=torch.device('cuda'))
#       4 wavenetModel = wavenetModel.to('cpu')
#
# Cell In[31], line 17, in WaveNet.__init__(self, layer_size, stack_size, in_channels, res_channels)
#      13 self.receptive_fields = self.calc_receptive_fields(layer_size, stack_size)
#      15 self.causal = CausalConv1d(in_channels, res_channels)
# ---> 17 self.res_stack = ResidualStack(layer_size, stack_size, res_channels, in_channels)
#      19 self.densnet = DensNet(in_channels)
#      21 self.loss_fun = nn.MSELoss()
#
# Cell In[30], line 123, in ResidualStack.__init__(self, layer_size, stack_size, res_channels, skip_channels, device)
#     120 self.stack_size = stack_size
#     122 self.device = device
# --> 123 self.res_blocks = self.stack_res_block(res_channels, skip_channels)
#
# Cell In[30], line 157, in ResidualStack.stack_res_block(self, res_channels, skip_channels)
#     154 dilations = self.build_dilations()
#     156 for dilation in dilations:
# --> 157     block = self._residual_block(res_channels, skip_channels, dilation)
#     158     res_blocks.append(block)
#     160 return res_blocks
#
# Cell In[30], line 133, in ResidualStack._residual_block(res_channels, skip_channels, dilation)
#     129 if torch.cuda.device_count() > 1:
#     130     block = torch.nn.DataParallel(block)
# --> 133 block.to(self.device)
#     135 return block
#
# NameError: name 'self' is not defined

# %%
size_of_tensor(waveform)/1024/1024

# %%
t = torch.cuda.get_device_properties(0).total_memory
r = torch.cuda.memory_reserved(0)
a = torch.cuda.memory_allocated(0)
f = r-a  # free inside reserved
a/1024/1024/1024, r/1024/1024/1024, t/1024/1024/1024

# %%
#with torch.no_grad():
wavenetModel(waveform)

# %%
#modelPanoramico = WaveNetPanoramico(layer_size=18, stack_size=2, in_channels=1, res_channels=128)
#modelPanoramico.load_state_dict(torch.load(modeloNombre))

# %%
#modeloPostnetNombre = '/content/drive/MyDrive/tesisPabloAxel/wavenet/modelos/wavenetReal/PostNetSimple12capas.pth'

# %%
#postnetModel = PostNetSimple()
#postnetModel.load_state_dict(torch.load(modeloPostnetNombre))

# %%
#wavenetModel = modelCargado
#WaveNet( layer_size=15, stack_size=2, in_channels=1, res_channels=128)
losses = []

# %%
loss_fn = nn.L1Loss()
learning_rate = 0.0015
optimizer = torch.optim.AdamW(params=wavenetModel.parameters(), lr=learning_rate)
#optimizerPost = torch.optim.AdamW(params=postnetModel.parameters(), lr=learning_rate)

mel_transform1 = transformsaudio.MelSpectrogram(sample_rate = 16000,
                                               n_fft = 2048,
                                                n_mels = 120,
                                                hop_length = 512).to('cuda')

mel_transform2 = transformsaudio.MelSpectrogram(sample_rate = 16000,
                                               n_fft = 512,
                                                n_mels = 80,
                                                hop_length = 128).to('cuda')

# %%
def prepareSpectogram(melspect):
    melspect = ((melspect - melspect.min()) / (melspect.max()-melspect.min()) + 0.00000001)
    melspect=melspect.log10()
    min_db = -6
    # Clamp the values in the tensor to be no less than min_db
    melspect = melspect.clamp(min=min_db)
    return melspect

# %%
def melspectogramLoss(y_pred, true_y):

  mel1true_y = (mel_transform1(true_y.to('cuda')))
  mel1y_pred = (mel_transform1(y_pred.to('cuda')))
  mel2true_y = (mel_transform2(true_y.to('cuda')))
  mel2y_pred = (mel_transform2(y_pred.to('cuda')))

  mel1true_y = prepareSpectogram(mel1true_y)
  mel1y_pred = prepareSpectogram(mel1y_pred)
  mel2true_y = prepareSpectogram(mel2true_y)
  mel2y_pred = prepareSpectogram(mel2y_pred)

  dif1 = (mel1true_y - mel1y_pred).abs().mean()
  dif2 = (mel2true_y - mel2y_pred).abs().mean()
  # Define the minimum dB value


  return dif1*15 , dif2*10

# %%
batch_size = 3

dataset = AudioCleaningDataset(directoryBase+'/CSV/audio_pocos.csv', directoryBase+'/audiosDivididos/', directoryBase+'/audiosDivididos/ruidosPocos/', directoryBase+"/audiosDivididos/reverbPocos")
dataloader = DataLoader(dataset, batch_size=batch_size, shuffle=True)

# %%
melspectogramLoss(waveform, label)

# %%
losses = []

# %%
# %tensorboard --logdir=runs

# %%
NUM_EPOCHS = 10
for epoch in range(NUM_EPOCHS):
    avgLossOfBatch = []
    for i, (X, true_y) in enumerate(dataloader, 0):
        # zero gradients
        optimizer.zero_grad()
        # forward pass
        y_pred = wavenetModel(X.to("cuda"))
        #y_pred_postnet = postnetModel(y_pred)
        # calc losses

        lossAudio = loss_fn(y_pred, true_y) * 10
        lossSpect1, lossSpect2 = melspectogramLoss(y_pred, true_y)


        loss = lossAudio + lossSpect1 + lossSpect2
        #lossSpectPost1, lossSpectPost2 = melspectogramLoss(y_pred_postnet, true_y)
        #lossPostnet = loss_fn(y_pred_postnet, true_y) * 10 + lossSpectPost1 + lossSpectPost2
        # backward pass
        loss.backward()
        #lossPostnet.backward()
        # update weights
        optimizer.step()
        #optimizerPost.step()

        avgLossOfBatch.append(loss.item())
        xs = 2917 * epoch + i
        writer.add_scalar("Loss audio", lossAudio, xs)
        writer.add_scalar("Loss spect1", lossSpect1, xs)
        writer.add_scalar("Loss spect2", lossSpect2, xs)
        writer.add_scalar("Loss spect all", lossSpect1 + lossSpect2, xs)

        writer.add_scalar("Loss total", loss, i)

        if((i%1)==0):
          print(str(round(100*(i)/(2917/batch_size),2)) + "% del epoch " + str(epoch))
          prom = np.array(avgLossOfBatch).mean()
          losses.append(prom)
          avgLossOfBatch = []
          #print(prom)
          print("Perdida de wavenet: ")
          print(loss)
          print()
          print(lossAudio)
          print(lossSpect1)
          print(lossSpect2)
          #torch.save(wavenetModel.state_dict(), modeloNombre)
          torch.save(wavenetModel, modeloNombre)
            #torch.save(postnetModel.state_dict(), modeloPostnetNombre)
# Out:
# 0.0% del epoch 0
# Perdida de wavenet:
# tensor(2.1104, device='cuda:0', grad_fn=<AddBackward0>)
#
# tensor(0.0461, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(1.0223, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(1.0420, device='cuda:0', grad_fn=<MulBackward0>)
# 0.1% del epoch 0
# Perdida de wavenet:
# tensor(1.7868, device='cuda:0', grad_fn=<AddBackward0>)
#
# tensor(0.0688, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(0.8075, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(0.9105, device='cuda:0', grad_fn=<MulBackward0>)
# 0.21% del epoch 0
# Perdida de wavenet:
# tensor(2.0249, device='cuda:0', grad_fn=<AddBackward0>)
#
# tensor(0.0557, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(0.9928, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(0.9764, device='cuda:0', grad_fn=<MulBackward0>)
# 0.31% del epoch 0
# Perdida de wavenet:
# tensor(1.7848, device='cuda:0', grad_fn=<AddBackward0>)
#
# tensor(0.0533, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(0.8570, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(0.8745, device='cuda:0', grad_fn=<MulBackward0>)
# 0.41% del epoch 0
# Perdida de wavenet:
# tensor(2.2721, device='cuda:0', grad_fn=<AddBackward0>)
#
# tensor(0.0719, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(1.0584, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(1.1417, device='cuda:0', grad_fn=<MulBackward0>)
# 0.51% del epoch 0
# Perdida de wavenet:
# tensor(2.4001, device='cuda:0', grad_fn=<AddBackward0>)
#
# tensor(0.0944, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(1.1817, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(1.1240, device='cuda:0', grad_fn=<MulBackward0>)
# 0.62% del epoch 0
# Perdida de wavenet:
# tensor(2.2239, device='cuda:0', grad_fn=<AddBackward0>)
#
# tensor(0.1043, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(1.1068, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(1.0127, device='cuda:0', grad_fn=<MulBackward0>)
# 0.72% del epoch 0
# Perdida de wavenet:
# tensor(1.2742, device='cuda:0', grad_fn=<AddBackward0>)
#
# tensor(0.0328, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(0.6344, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(0.6069, device='cuda:0', grad_fn=<MulBackward0>)
# 0.82% del epoch 0
# Perdida de wavenet:
# tensor(1.7378, device='cuda:0', grad_fn=<AddBackward0>)
#
# tensor(0.0369, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(0.8533, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(0.8476, device='cuda:0', grad_fn=<MulBackward0>)
# 0.93% del epoch 0
# Perdida de wavenet:
# tensor(2.1697, device='cuda:0', grad_fn=<AddBackward0>)
#
# tensor(0.0692, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(1.0588, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(1.0417, device='cuda:0', grad_fn=<MulBackward0>)
# 1.03% del epoch 0
# Perdida de wavenet:
# tensor(1.3858, device='cuda:0', grad_fn=<AddBackward0>)
#
# tensor(0.0650, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(0.6767, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(0.6441, device='cuda:0', grad_fn=<MulBackward0>)
# 1.13% del epoch 0
# Perdida de wavenet:
# tensor(1.8746, device='cuda:0', grad_fn=<AddBackward0>)
#
# tensor(0.0461, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(0.8956, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(0.9329, device='cuda:0', grad_fn=<MulBackward0>)
# 1.23% del epoch 0
# Perdida de wavenet:
# tensor(1.1833, device='cuda:0', grad_fn=<AddBackward0>)
#
# tensor(0.0301, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(0.5960, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(0.5571, device='cuda:0', grad_fn=<MulBackward0>)
# 1.34% del epoch 0
# Perdida de wavenet:
# tensor(1.6647, device='cuda:0', grad_fn=<AddBackward0>)
#
# tensor(0.0667, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(0.8782, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(0.7197, device='cuda:0', grad_fn=<MulBackward0>)
# 1.44% del epoch 0
# Perdida de wavenet:
# tensor(1.5783, device='cuda:0', grad_fn=<AddBackward0>)
#
# tensor(0.0347, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(0.8100, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(0.7335, device='cuda:0', grad_fn=<MulBackward0>)
# 1.54% del epoch 0
# Perdida de wavenet:
# tensor(2.3428, device='cuda:0', grad_fn=<AddBackward0>)
#
# tensor(0.0520, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(1.1059, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(1.1849, device='cuda:0', grad_fn=<MulBackward0>)
# 1.65% del epoch 0
# Perdida de wavenet:
# tensor(1.3734, device='cuda:0', grad_fn=<AddBackward0>)
#
# tensor(0.0375, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(0.6739, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(0.6620, device='cuda:0', grad_fn=<MulBackward0>)
# 1.75% del epoch 0
# Perdida de wavenet:
# tensor(1.9569, device='cuda:0', grad_fn=<AddBackward0>)
#
# tensor(0.0665, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(0.9937, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(0.8967, device='cuda:0', grad_fn=<MulBackward0>)
# 1.85% del epoch 0
# Perdida de wavenet:
# tensor(1.9787, device='cuda:0', grad_fn=<AddBackward0>)
#
# tensor(0.0633, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(0.9514, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(0.9640, device='cuda:0', grad_fn=<MulBackward0>)
# 1.95% del epoch 0
# Perdida de wavenet:
# tensor(2.1085, device='cuda:0', grad_fn=<AddBackward0>)
#
# tensor(0.0589, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(1.1625, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(0.8871, device='cuda:0', grad_fn=<MulBackward0>)
# 2.06% del epoch 0
# Perdida de wavenet:
# tensor(1.8504, device='cuda:0', grad_fn=<AddBackward0>)
#
# tensor(0.0617, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(0.8954, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(0.8933, device='cuda:0', grad_fn=<MulBackward0>)
# 2.16% del epoch 0
# Perdida de wavenet:
# tensor(1.9289, device='cuda:0', grad_fn=<AddBackward0>)
#
# tensor(0.0701, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(0.9264, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(0.9324, device='cuda:0', grad_fn=<MulBackward0>)
# 2.26% del epoch 0
# Perdida de wavenet:
# tensor(1.8152, device='cuda:0', grad_fn=<AddBackward0>)
#
# tensor(0.0776, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(0.8652, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(0.8724, device='cuda:0', grad_fn=<MulBackward0>)
# 2.37% del epoch 0
# Perdida de wavenet:
# tensor(1.1644, device='cuda:0', grad_fn=<AddBackward0>)
#
# tensor(0.0532, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(0.5461, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(0.5652, device='cuda:0', grad_fn=<MulBackward0>)
# 2.47% del epoch 0
# Perdida de wavenet:
# tensor(1.6448, device='cuda:0', grad_fn=<AddBackward0>)
#
# tensor(0.0734, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(0.7804, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(0.7910, device='cuda:0', grad_fn=<MulBackward0>)
# 2.57% del epoch 0
# Perdida de wavenet:
# tensor(1.2362, device='cuda:0', grad_fn=<AddBackward0>)
#
# tensor(0.0640, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(0.6420, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(0.5302, device='cuda:0', grad_fn=<MulBackward0>)
# 2.67% del epoch 0
# Perdida de wavenet:
# tensor(1.6016, device='cuda:0', grad_fn=<AddBackward0>)
#
# tensor(0.0277, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(0.9047, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(0.6692, device='cuda:0', grad_fn=<MulBackward0>)
# 2.78% del epoch 0
# Perdida de wavenet:
# tensor(1.9757, device='cuda:0', grad_fn=<AddBackward0>)
#
# tensor(0.0639, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(0.9676, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(0.9442, device='cuda:0', grad_fn=<MulBackward0>)
# 2.88% del epoch 0
# Perdida de wavenet:
# tensor(1.2989, device='cuda:0', grad_fn=<AddBackward0>)
#
# tensor(0.0457, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(0.6948, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(0.5584, device='cuda:0', grad_fn=<MulBackward0>)
# 2.98% del epoch 0
# Perdida de wavenet:
# tensor(1.2118, device='cuda:0', grad_fn=<AddBackward0>)
#
# tensor(0.0634, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(0.6573, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(0.4912, device='cuda:0', grad_fn=<MulBackward0>)
# 3.09% del epoch 0
# Perdida de wavenet:
# tensor(1.3346, device='cuda:0', grad_fn=<AddBackward0>)
#
# tensor(0.0555, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(0.6431, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(0.6360, device='cuda:0', grad_fn=<MulBackward0>)
# 3.19% del epoch 0
# Perdida de wavenet:
# tensor(1.3089, device='cuda:0', grad_fn=<AddBackward0>)
#
# tensor(0.0370, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(0.6438, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(0.6281, device='cuda:0', grad_fn=<MulBackward0>)
# 3.29% del epoch 0
# Perdida de wavenet:
# tensor(1.6412, device='cuda:0', grad_fn=<AddBackward0>)
#
# tensor(0.0514, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(0.7647, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(0.8251, device='cuda:0', grad_fn=<MulBackward0>)
# 3.39% del epoch 0
# Perdida de wavenet:
# tensor(1.6589, device='cuda:0', grad_fn=<AddBackward0>)
#
# tensor(0.0686, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(0.8132, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(0.7770, device='cuda:0', grad_fn=<MulBackward0>)
# 3.5% del epoch 0
# Perdida de wavenet:
# tensor(1.2273, device='cuda:0', grad_fn=<AddBackward0>)
#
# tensor(0.0350, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(0.5695, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(0.6229, device='cuda:0', grad_fn=<MulBackward0>)
# 3.6% del epoch 0
# Perdida de wavenet:
# tensor(1.4976, device='cuda:0', grad_fn=<AddBackward0>)
#
# tensor(0.0698, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(0.7556, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(0.6722, device='cuda:0', grad_fn=<MulBackward0>)
# 3.7% del epoch 0
# Perdida de wavenet:
# tensor(1.4487, device='cuda:0', grad_fn=<AddBackward0>)
#
# tensor(0.0417, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(0.7671, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(0.6399, device='cuda:0', grad_fn=<MulBackward0>)
# 3.81% del epoch 0
# Perdida de wavenet:
# tensor(1.6320, device='cuda:0', grad_fn=<AddBackward0>)
#
# tensor(0.0394, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(0.8235, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(0.7690, device='cuda:0', grad_fn=<MulBackward0>)
# 3.91% del epoch 0
# Perdida de wavenet:
# tensor(1.4698, device='cuda:0', grad_fn=<AddBackward0>)
#
# tensor(0.0689, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(0.7216, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(0.6792, device='cuda:0', grad_fn=<MulBackward0>)
# 4.01% del epoch 0
# Perdida de wavenet:
# tensor(2.1470, device='cuda:0', grad_fn=<AddBackward0>)
#
# tensor(0.0363, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(0.9837, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(1.1270, device='cuda:0', grad_fn=<MulBackward0>)
# 4.11% del epoch 0
# Perdida de wavenet:
# tensor(2.0568, device='cuda:0', grad_fn=<AddBackward0>)
#
# tensor(0.0760, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(1.0476, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(0.9332, device='cuda:0', grad_fn=<MulBackward0>)
# 4.22% del epoch 0
# Perdida de wavenet:
# tensor(1.6296, device='cuda:0', grad_fn=<AddBackward0>)
#
# tensor(0.0951, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(0.7852, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(0.7493, device='cuda:0', grad_fn=<MulBackward0>)
# 4.32% del epoch 0
# Perdida de wavenet:
# tensor(2.2186, device='cuda:0', grad_fn=<AddBackward0>)
#
# tensor(0.0556, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(1.0843, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(1.0787, device='cuda:0', grad_fn=<MulBackward0>)
# 4.42% del epoch 0
# Perdida de wavenet:
# tensor(1.4006, device='cuda:0', grad_fn=<AddBackward0>)
#
# tensor(0.0689, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(0.6440, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(0.6877, device='cuda:0', grad_fn=<MulBackward0>)
# 4.53% del epoch 0
# Perdida de wavenet:
# tensor(1.2419, device='cuda:0', grad_fn=<AddBackward0>)
#
# tensor(0.0589, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(0.6192, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(0.5638, device='cuda:0', grad_fn=<MulBackward0>)
# 4.63% del epoch 0
# Perdida de wavenet:
# tensor(1.5705, device='cuda:0', grad_fn=<AddBackward0>)
#
# tensor(0.0554, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(0.8286, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(0.6864, device='cuda:0', grad_fn=<MulBackward0>)
# 4.73% del epoch 0
# Perdida de wavenet:
# tensor(2.1669, device='cuda:0', grad_fn=<AddBackward0>)
#
# tensor(0.0655, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(1.2016, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(0.8998, device='cuda:0', grad_fn=<MulBackward0>)
# 0.0% del epoch 1
# Perdida de wavenet:
# tensor(1.3323, device='cuda:0', grad_fn=<AddBackward0>)
#
# tensor(0.0522, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(0.7610, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(0.5191, device='cuda:0', grad_fn=<MulBackward0>)
# 0.1% del epoch 1
# Perdida de wavenet:
# tensor(1.8406, device='cuda:0', grad_fn=<AddBackward0>)
#
# tensor(0.0892, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(0.9537, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(0.7977, device='cuda:0', grad_fn=<MulBackward0>)
# 0.21% del epoch 1
# Perdida de wavenet:
# tensor(1.5359, device='cuda:0', grad_fn=<AddBackward0>)
#
# tensor(0.0254, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(0.7399, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(0.7705, device='cuda:0', grad_fn=<MulBackward0>)
# 0.31% del epoch 1
# Perdida de wavenet:
# tensor(1.4888, device='cuda:0', grad_fn=<AddBackward0>)
#
# tensor(0.0515, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(0.7447, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(0.6925, device='cuda:0', grad_fn=<MulBackward0>)
# 0.41% del epoch 1
# Perdida de wavenet:
# tensor(1.8297, device='cuda:0', grad_fn=<AddBackward0>)
#
# tensor(0.0591, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(0.9106, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(0.8600, device='cuda:0', grad_fn=<MulBackward0>)
# 0.51% del epoch 1
# Perdida de wavenet:
# tensor(1.6991, device='cuda:0', grad_fn=<AddBackward0>)
#
# tensor(0.0743, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(0.9089, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(0.7160, device='cuda:0', grad_fn=<MulBackward0>)
# 0.62% del epoch 1
# Perdida de wavenet:
# tensor(1.4557, device='cuda:0', grad_fn=<AddBackward0>)
#
# tensor(0.0599, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(0.7562, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(0.6397, device='cuda:0', grad_fn=<MulBackward0>)
# 0.72% del epoch 1
# Perdida de wavenet:
# tensor(1.5658, device='cuda:0', grad_fn=<AddBackward0>)
#
# tensor(0.0502, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(0.7305, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(0.7851, device='cuda:0', grad_fn=<MulBackward0>)
# 0.82% del epoch 1
# Perdida de wavenet:
# tensor(1.6182, device='cuda:0', grad_fn=<AddBackward0>)
#
# tensor(0.0453, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(0.7859, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(0.7870, device='cuda:0', grad_fn=<MulBackward0>)
# 0.93% del epoch 1
# Perdida de wavenet:
# tensor(1.4318, device='cuda:0', grad_fn=<AddBackward0>)
#
# tensor(0.0254, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(0.6718, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(0.7346, device='cuda:0', grad_fn=<MulBackward0>)
# 1.03% del epoch 1
# Perdida de wavenet:
# tensor(1.8896, device='cuda:0', grad_fn=<AddBackward0>)
#
# tensor(0.0913, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(0.9422, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(0.8561, device='cuda:0', grad_fn=<MulBackward0>)
# 1.13% del epoch 1
# Perdida de wavenet:
# tensor(1.2938, device='cuda:0', grad_fn=<AddBackward0>)
#
# tensor(0.0617, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(0.6207, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(0.6114, device='cuda:0', grad_fn=<MulBackward0>)
# 1.23% del epoch 1
# Perdida de wavenet:
# tensor(1.4399, device='cuda:0', grad_fn=<AddBackward0>)
#
# tensor(0.0486, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(0.7280, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(0.6633, device='cuda:0', grad_fn=<MulBackward0>)
# 1.34% del epoch 1
# Perdida de wavenet:
# tensor(1.8566, device='cuda:0', grad_fn=<AddBackward0>)
#
# tensor(0.0632, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(0.8560, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(0.9374, device='cuda:0', grad_fn=<MulBackward0>)
# 1.44% del epoch 1
# Perdida de wavenet:
# tensor(1.7382, device='cuda:0', grad_fn=<AddBackward0>)
#
# tensor(0.0864, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(0.8844, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(0.7674, device='cuda:0', grad_fn=<MulBackward0>)
# 1.54% del epoch 1
# Perdida de wavenet:
# tensor(1.2190, device='cuda:0', grad_fn=<AddBackward0>)
#
# tensor(0.0285, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(0.6352, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(0.5554, device='cuda:0', grad_fn=<MulBackward0>)
# 1.65% del epoch 1
# Perdida de wavenet:
# tensor(1.9484, device='cuda:0', grad_fn=<AddBackward0>)
#
# tensor(0.0522, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(1.1872, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(0.7089, device='cuda:0', grad_fn=<MulBackward0>)
# 1.75% del epoch 1
# Perdida de wavenet:
# tensor(1.4419, device='cuda:0', grad_fn=<AddBackward0>)
#
# tensor(0.0553, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(0.7082, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(0.6784, device='cuda:0', grad_fn=<MulBackward0>)
# 1.85% del epoch 1
# Perdida de wavenet:
# tensor(1.6188, device='cuda:0', grad_fn=<AddBackward0>)
#
# tensor(0.0833, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(0.7639, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(0.7716, device='cuda:0', grad_fn=<MulBackward0>)
# 1.95% del epoch 1
# Perdida de wavenet:
# tensor(1.8693, device='cuda:0', grad_fn=<AddBackward0>)
#
# tensor(0.0506, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(0.9045, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(0.9142, device='cuda:0', grad_fn=<MulBackward0>)
# 2.06% del epoch 1
# Perdida de wavenet:
# tensor(1.6960, device='cuda:0', grad_fn=<AddBackward0>)
#
# tensor(0.0342, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(0.7708, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(0.8911, device='cuda:0', grad_fn=<MulBackward0>)
# 2.16% del epoch 1
# Perdida de wavenet:
# tensor(1.5445, device='cuda:0', grad_fn=<AddBackward0>)
#
# tensor(0.0452, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(0.8012, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(0.6981, device='cuda:0', grad_fn=<MulBackward0>)
# 2.26% del epoch 1
# Perdida de wavenet:
# tensor(2.0971, device='cuda:0', grad_fn=<AddBackward0>)
#
# tensor(0.0618, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(1.1035, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(0.9319, device='cuda:0', grad_fn=<MulBackward0>)
# 2.37% del epoch 1
# Perdida de wavenet:
# tensor(1.6119, device='cuda:0', grad_fn=<AddBackward0>)
#
# tensor(0.0415, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(0.8908, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(0.6796, device='cuda:0', grad_fn=<MulBackward0>)
# 2.47% del epoch 1
# Perdida de wavenet:
# tensor(1.8767, device='cuda:0', grad_fn=<AddBackward0>)
#
# tensor(0.0385, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(0.9790, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(0.8593, device='cuda:0', grad_fn=<MulBackward0>)
# 2.57% del epoch 1
# Perdida de wavenet:
# tensor(2.0757, device='cuda:0', grad_fn=<AddBackward0>)
#
# tensor(0.0694, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(1.0881, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(0.9181, device='cuda:0', grad_fn=<MulBackward0>)
# 2.67% del epoch 1
# Perdida de wavenet:
# tensor(1.8694, device='cuda:0', grad_fn=<AddBackward0>)
#
# tensor(0.0655, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(0.9179, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(0.8860, device='cuda:0', grad_fn=<MulBackward0>)
# 2.78% del epoch 1
# Perdida de wavenet:
# tensor(1.7710, device='cuda:0', grad_fn=<AddBackward0>)
#
# tensor(0.0286, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(0.8922, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(0.8501, device='cuda:0', grad_fn=<MulBackward0>)
# 2.88% del epoch 1
# Perdida de wavenet:
# tensor(1.5310, device='cuda:0', grad_fn=<AddBackward0>)
#
# tensor(0.0391, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(0.6877, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(0.8042, device='cuda:0', grad_fn=<MulBackward0>)
# 2.98% del epoch 1
# Perdida de wavenet:
# tensor(1.5184, device='cuda:0', grad_fn=<AddBackward0>)
#
# tensor(0.0442, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(0.7102, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(0.7640, device='cuda:0', grad_fn=<MulBackward0>)
# 3.09% del epoch 1
# Perdida de wavenet:
# tensor(1.8163, device='cuda:0', grad_fn=<AddBackward0>)
#
# tensor(0.0255, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(0.8815, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(0.9093, device='cuda:0', grad_fn=<MulBackward0>)
# 3.19% del epoch 1
# Perdida de wavenet:
# tensor(34.1203, device='cuda:0', grad_fn=<AddBackward0>)
#
# tensor(0.0193, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(20.0113, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(14.0897, device='cuda:0', grad_fn=<MulBackward0>)
# 3.29% del epoch 1
# Perdida de wavenet:
# tensor(1.6738, device='cuda:0', grad_fn=<AddBackward0>)
#
# tensor(0.0633, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(0.7860, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(0.8246, device='cuda:0', grad_fn=<MulBackward0>)
# 3.39% del epoch 1
# Perdida de wavenet:
# tensor(1.6711, device='cuda:0', grad_fn=<AddBackward0>)
#
# tensor(0.0527, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(0.8588, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(0.7596, device='cuda:0', grad_fn=<MulBackward0>)
# 3.5% del epoch 1
# Perdida de wavenet:
# tensor(1.6432, device='cuda:0', grad_fn=<AddBackward0>)
#
# tensor(0.0494, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(0.8306, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(0.7632, device='cuda:0', grad_fn=<MulBackward0>)
# 3.6% del epoch 1
# Perdida de wavenet:
# tensor(1.6537, device='cuda:0', grad_fn=<AddBackward0>)
#
# tensor(0.0557, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(0.7578, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(0.8402, device='cuda:0', grad_fn=<MulBackward0>)
# 3.7% del epoch 1
# Perdida de wavenet:
# tensor(2.5663, device='cuda:0', grad_fn=<AddBackward0>)
#
# tensor(0.1000, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(1.5012, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(0.9651, device='cuda:0', grad_fn=<MulBackward0>)
# 3.81% del epoch 1
# Perdida de wavenet:
# tensor(1.6209, device='cuda:0', grad_fn=<AddBackward0>)
#
# tensor(0.0553, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(0.7822, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(0.7833, device='cuda:0', grad_fn=<MulBackward0>)
# 3.91% del epoch 1
# Perdida de wavenet:
# tensor(1.3396, device='cuda:0', grad_fn=<AddBackward0>)
#
# tensor(0.0478, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(0.6788, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(0.6130, device='cuda:0', grad_fn=<MulBackward0>)
# 4.01% del epoch 1
# Perdida de wavenet:
# tensor(2.2237, device='cuda:0', grad_fn=<AddBackward0>)
#
# tensor(0.0579, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(1.1529, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(1.0129, device='cuda:0', grad_fn=<MulBackward0>)
# 4.11% del epoch 1
# Perdida de wavenet:
# tensor(2.0926, device='cuda:0', grad_fn=<AddBackward0>)
#
# tensor(0.0456, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(1.0322, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(1.0149, device='cuda:0', grad_fn=<MulBackward0>)
# 4.22% del epoch 1
# Perdida de wavenet:
# tensor(1.6290, device='cuda:0', grad_fn=<AddBackward0>)
#
# tensor(0.0517, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(0.8287, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(0.7486, device='cuda:0', grad_fn=<MulBackward0>)
# 4.32% del epoch 1
# Perdida de wavenet:
# tensor(1.7424, device='cuda:0', grad_fn=<AddBackward0>)
#
# tensor(0.0498, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(0.9766, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(0.7161, device='cuda:0', grad_fn=<MulBackward0>)
# 4.42% del epoch 1
# Perdida de wavenet:
# tensor(1.9635, device='cuda:0', grad_fn=<AddBackward0>)
#
# tensor(0.0548, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(1.0793, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(0.8294, device='cuda:0', grad_fn=<MulBackward0>)
# 4.53% del epoch 1
# Perdida de wavenet:
# tensor(1.8070, device='cuda:0', grad_fn=<AddBackward0>)
#
# tensor(0.0580, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(0.9107, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(0.8383, device='cuda:0', grad_fn=<MulBackward0>)
# 4.63% del epoch 1
# Perdida de wavenet:
# tensor(1.0940, device='cuda:0', grad_fn=<AddBackward0>)
#
# tensor(0.0484, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(0.5322, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(0.5134, device='cuda:0', grad_fn=<MulBackward0>)
# 4.73% del epoch 1
# Perdida de wavenet:
# tensor(1.6127, device='cuda:0', grad_fn=<AddBackward0>)
#
# tensor(0.0802, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(0.7265, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(0.8060, device='cuda:0', grad_fn=<MulBackward0>)
# 0.0% del epoch 2
# Perdida de wavenet:
# tensor(1.8421, device='cuda:0', grad_fn=<AddBackward0>)
#
# tensor(0.0884, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(0.8468, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(0.9070, device='cuda:0', grad_fn=<MulBackward0>)
# 0.1% del epoch 2
# Perdida de wavenet:
# tensor(1.5544, device='cuda:0', grad_fn=<AddBackward0>)
#
# tensor(0.0409, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(0.9069, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(0.6066, device='cuda:0', grad_fn=<MulBackward0>)
# 0.21% del epoch 2
# Perdida de wavenet:
# tensor(2.3279, device='cuda:0', grad_fn=<AddBackward0>)
#
# tensor(0.0540, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(1.1143, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(1.1597, device='cuda:0', grad_fn=<MulBackward0>)
# 0.31% del epoch 2
# Perdida de wavenet:
# tensor(1.4563, device='cuda:0', grad_fn=<AddBackward0>)
#
# tensor(0.0452, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(0.7036, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(0.7075, device='cuda:0', grad_fn=<MulBackward0>)
# 0.41% del epoch 2
# Perdida de wavenet:
# tensor(1.1120, device='cuda:0', grad_fn=<AddBackward0>)
#
# tensor(0.0409, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(0.5461, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(0.5249, device='cuda:0', grad_fn=<MulBackward0>)
# 0.51% del epoch 2
# Perdida de wavenet:
# tensor(1.5341, device='cuda:0', grad_fn=<AddBackward0>)
#
# tensor(0.0812, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(0.7783, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(0.6746, device='cuda:0', grad_fn=<MulBackward0>)
# 0.62% del epoch 2
# Perdida de wavenet:
# tensor(1.4329, device='cuda:0', grad_fn=<AddBackward0>)
#
# tensor(0.0343, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(0.7421, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(0.6565, device='cuda:0', grad_fn=<MulBackward0>)
# 0.72% del epoch 2
# Perdida de wavenet:
# tensor(3.9190, device='cuda:0', grad_fn=<AddBackward0>)
#
# tensor(0.0195, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(2.6636, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(1.2360, device='cuda:0', grad_fn=<MulBackward0>)
# 0.82% del epoch 2
# Perdida de wavenet:
# tensor(1.2435, device='cuda:0', grad_fn=<AddBackward0>)
#
# tensor(0.0407, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(0.6591, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(0.5437, device='cuda:0', grad_fn=<MulBackward0>)
# 0.93% del epoch 2
# Perdida de wavenet:
# tensor(1.3672, device='cuda:0', grad_fn=<AddBackward0>)
#
# tensor(0.0409, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(0.6548, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(0.6715, device='cuda:0', grad_fn=<MulBackward0>)
# 1.03% del epoch 2
# Perdida de wavenet:
# tensor(1.5129, device='cuda:0', grad_fn=<AddBackward0>)
#
# tensor(0.0800, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(0.7939, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(0.6390, device='cuda:0', grad_fn=<MulBackward0>)
# 1.13% del epoch 2
# Perdida de wavenet:
# tensor(1.9979, device='cuda:0', grad_fn=<AddBackward0>)
#
# tensor(0.0507, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(1.0400, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(0.9072, device='cuda:0', grad_fn=<MulBackward0>)
# 1.23% del epoch 2
# Perdida de wavenet:
# tensor(2.0595, device='cuda:0', grad_fn=<AddBackward0>)
#
# tensor(0.0676, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(1.0114, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(0.9806, device='cuda:0', grad_fn=<MulBackward0>)
# 1.34% del epoch 2
# Perdida de wavenet:
# tensor(1.8875, device='cuda:0', grad_fn=<AddBackward0>)
#
# tensor(0.0579, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(0.9701, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(0.8596, device='cuda:0', grad_fn=<MulBackward0>)
# 1.44% del epoch 2
# Perdida de wavenet:
# tensor(1.7707, device='cuda:0', grad_fn=<AddBackward0>)
#
# tensor(0.0639, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(0.8458, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(0.8611, device='cuda:0', grad_fn=<MulBackward0>)
# 1.54% del epoch 2
# Perdida de wavenet:
# tensor(1.3996, device='cuda:0', grad_fn=<AddBackward0>)
#
# tensor(0.0571, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(0.6703, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(0.6722, device='cuda:0', grad_fn=<MulBackward0>)
# 1.65% del epoch 2
# Perdida de wavenet:
# tensor(1.9488, device='cuda:0', grad_fn=<AddBackward0>)
#
# tensor(0.0612, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(0.9718, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(0.9158, device='cuda:0', grad_fn=<MulBackward0>)
# 1.75% del epoch 2
# Perdida de wavenet:
# tensor(1.7705, device='cuda:0', grad_fn=<AddBackward0>)
#
# tensor(0.0574, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(0.8568, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(0.8563, device='cuda:0', grad_fn=<MulBackward0>)
# 1.85% del epoch 2
# Perdida de wavenet:
# tensor(1.4619, device='cuda:0', grad_fn=<AddBackward0>)
#
# tensor(0.0629, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(0.7595, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(0.6395, device='cuda:0', grad_fn=<MulBackward0>)
# 1.95% del epoch 2
# Perdida de wavenet:
# tensor(1.4170, device='cuda:0', grad_fn=<AddBackward0>)
#
# tensor(0.0474, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(0.6620, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(0.7076, device='cuda:0', grad_fn=<MulBackward0>)
# 2.06% del epoch 2
# Perdida de wavenet:
# tensor(2.5696, device='cuda:0', grad_fn=<AddBackward0>)
#
# tensor(0.1261, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(1.2850, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(1.1585, device='cuda:0', grad_fn=<MulBackward0>)
# 2.16% del epoch 2
# Perdida de wavenet:
# tensor(1.0164, device='cuda:0', grad_fn=<AddBackward0>)
#
# tensor(0.0282, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(0.5460, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(0.4422, device='cuda:0', grad_fn=<MulBackward0>)
# 2.26% del epoch 2
# Perdida de wavenet:
# tensor(1.5175, device='cuda:0', grad_fn=<AddBackward0>)
#
# tensor(0.0602, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(0.7332, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(0.7241, device='cuda:0', grad_fn=<MulBackward0>)
# 2.37% del epoch 2
# Perdida de wavenet:
# tensor(1.2352, device='cuda:0', grad_fn=<AddBackward0>)
#
# tensor(0.0407, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(0.5452, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(0.6494, device='cuda:0', grad_fn=<MulBackward0>)
# 2.47% del epoch 2
# Perdida de wavenet:
# tensor(1.6541, device='cuda:0', grad_fn=<AddBackward0>)
#
# tensor(0.0715, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(0.9075, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(0.6750, device='cuda:0', grad_fn=<MulBackward0>)
# 2.57% del epoch 2
# Perdida de wavenet:
# tensor(1.6222, device='cuda:0', grad_fn=<AddBackward0>)
#
# tensor(0.0477, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(0.8305, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(0.7440, device='cuda:0', grad_fn=<MulBackward0>)
# 2.67% del epoch 2
# Perdida de wavenet:
# tensor(1.9058, device='cuda:0', grad_fn=<AddBackward0>)
#
# tensor(0.0748, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(0.9444, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(0.8866, device='cuda:0', grad_fn=<MulBackward0>)
# 2.78% del epoch 2
# Perdida de wavenet:
# tensor(1.6301, device='cuda:0', grad_fn=<AddBackward0>)
#
# tensor(0.0398, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(0.9144, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(0.6759, device='cuda:0', grad_fn=<MulBackward0>)
# 2.88% del epoch 2
# Perdida de wavenet:
# tensor(1.3953, device='cuda:0', grad_fn=<AddBackward0>)
#
# tensor(0.0723, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(0.7287, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(0.5943, device='cuda:0', grad_fn=<MulBackward0>)
# 2.98% del epoch 2
# Perdida de wavenet:
# tensor(2.1510, device='cuda:0', grad_fn=<AddBackward0>)
#
# tensor(0.0955, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(1.0230, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(1.0325, device='cuda:0', grad_fn=<MulBackward0>)
# 3.09% del epoch 2
# Perdida de wavenet:
# tensor(1.5874, device='cuda:0', grad_fn=<AddBackward0>)
#
# tensor(0.0438, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(0.7892, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(0.7544, device='cuda:0', grad_fn=<MulBackward0>)
# 3.19% del epoch 2
# Perdida de wavenet:
# tensor(2.0128, device='cuda:0', grad_fn=<AddBackward0>)
#
# tensor(0.0721, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(0.9241, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(1.0166, device='cuda:0', grad_fn=<MulBackward0>)
# 3.29% del epoch 2
# Perdida de wavenet:
# tensor(1.5918, device='cuda:0', grad_fn=<AddBackward0>)
#
# tensor(0.0471, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(0.9183, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(0.6265, device='cuda:0', grad_fn=<MulBackward0>)
# 3.39% del epoch 2
# Perdida de wavenet:
# tensor(1.1626, device='cuda:0', grad_fn=<AddBackward0>)
#
# tensor(0.0339, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(0.5490, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(0.5798, device='cuda:0', grad_fn=<MulBackward0>)
# 3.5% del epoch 2
# Perdida de wavenet:
# tensor(1.7094, device='cuda:0', grad_fn=<AddBackward0>)
#
# tensor(0.0541, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(0.8921, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(0.7632, device='cuda:0', grad_fn=<MulBackward0>)
# 3.6% del epoch 2
# Perdida de wavenet:
# tensor(1.7695, device='cuda:0', grad_fn=<AddBackward0>)
#
# tensor(0.0816, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(0.8127, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(0.8751, device='cuda:0', grad_fn=<MulBackward0>)
# 3.7% del epoch 2
# Perdida de wavenet:
# tensor(1.9364, device='cuda:0', grad_fn=<AddBackward0>)
#
# tensor(0.0948, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(0.9334, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(0.9082, device='cuda:0', grad_fn=<MulBackward0>)
# 3.81% del epoch 2
# Perdida de wavenet:
# tensor(1.6027, device='cuda:0', grad_fn=<AddBackward0>)
#
# tensor(0.0414, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(0.8809, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(0.6804, device='cuda:0', grad_fn=<MulBackward0>)
# 3.91% del epoch 2
# Perdida de wavenet:
# tensor(1.8519, device='cuda:0', grad_fn=<AddBackward0>)
#
# tensor(0.0669, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(0.9420, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(0.8430, device='cuda:0', grad_fn=<MulBackward0>)
# 4.01% del epoch 2
# Perdida de wavenet:
# tensor(1.9310, device='cuda:0', grad_fn=<AddBackward0>)
#
# tensor(0.0294, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(0.9855, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(0.9161, device='cuda:0', grad_fn=<MulBackward0>)
# 4.11% del epoch 2
# Perdida de wavenet:
# tensor(1.9896, device='cuda:0', grad_fn=<AddBackward0>)
#
# tensor(0.0844, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(0.9824, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(0.9228, device='cuda:0', grad_fn=<MulBackward0>)
# 4.22% del epoch 2
# Perdida de wavenet:
# tensor(1.8713, device='cuda:0', grad_fn=<AddBackward0>)
#
# tensor(0.0737, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(0.9496, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(0.8480, device='cuda:0', grad_fn=<MulBackward0>)
# 4.32% del epoch 2
# Perdida de wavenet:
# tensor(2.0391, device='cuda:0', grad_fn=<AddBackward0>)
#
# tensor(0.0880, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(1.0484, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(0.9027, device='cuda:0', grad_fn=<MulBackward0>)
# 4.42% del epoch 2
# Perdida de wavenet:
# tensor(1.4445, device='cuda:0', grad_fn=<AddBackward0>)
#
# tensor(0.0268, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(0.8009, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(0.6168, device='cuda:0', grad_fn=<MulBackward0>)
# 4.53% del epoch 2
# Perdida de wavenet:
# tensor(1.4668, device='cuda:0', grad_fn=<AddBackward0>)
#
# tensor(0.0492, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(0.6487, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(0.7689, device='cuda:0', grad_fn=<MulBackward0>)
# 4.63% del epoch 2
# Perdida de wavenet:
# tensor(1.1807, device='cuda:0', grad_fn=<AddBackward0>)
#
# tensor(0.0520, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(0.5784, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(0.5503, device='cuda:0', grad_fn=<MulBackward0>)
# 4.73% del epoch 2
# Perdida de wavenet:
# tensor(1.8418, device='cuda:0', grad_fn=<AddBackward0>)
#
# tensor(0.0330, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(0.9059, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(0.9029, device='cuda:0', grad_fn=<MulBackward0>)
# 0.0% del epoch 3
# Perdida de wavenet:
# tensor(2.5770, device='cuda:0', grad_fn=<AddBackward0>)
#
# tensor(0.0710, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(1.3626, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(1.1435, device='cuda:0', grad_fn=<MulBackward0>)
# 0.1% del epoch 3
# Perdida de wavenet:
# tensor(2.5782, device='cuda:0', grad_fn=<AddBackward0>)
#
# tensor(0.1311, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(1.2516, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(1.1955, device='cuda:0', grad_fn=<MulBackward0>)
# 0.21% del epoch 3
# Perdida de wavenet:
# tensor(1.9338, device='cuda:0', grad_fn=<AddBackward0>)
#
# tensor(0.0715, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(0.9534, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(0.9090, device='cuda:0', grad_fn=<MulBackward0>)
# 0.31% del epoch 3
# Perdida de wavenet:
# tensor(1.9112, device='cuda:0', grad_fn=<AddBackward0>)
#
# tensor(0.0826, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(0.9522, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(0.8765, device='cuda:0', grad_fn=<MulBackward0>)
# 0.41% del epoch 3
# Perdida de wavenet:
# tensor(1.9789, device='cuda:0', grad_fn=<AddBackward0>)
#
# tensor(0.0773, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(1.0464, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(0.8552, device='cuda:0', grad_fn=<MulBackward0>)
# 0.51% del epoch 3
# Perdida de wavenet:
# tensor(1.1824, device='cuda:0', grad_fn=<AddBackward0>)
#
# tensor(0.0465, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(0.6340, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(0.5019, device='cuda:0', grad_fn=<MulBackward0>)
# 0.62% del epoch 3
# Perdida de wavenet:
# tensor(1.3024, device='cuda:0', grad_fn=<AddBackward0>)
#
# tensor(0.0658, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(0.6788, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(0.5578, device='cuda:0', grad_fn=<MulBackward0>)
# 0.72% del epoch 3
# Perdida de wavenet:
# tensor(1.7601, device='cuda:0', grad_fn=<AddBackward0>)
#
# tensor(0.0583, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(0.9816, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(0.7202, device='cuda:0', grad_fn=<MulBackward0>)
# 0.82% del epoch 3
# Perdida de wavenet:
# tensor(1.6033, device='cuda:0', grad_fn=<AddBackward0>)
#
# tensor(0.0584, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(0.8312, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(0.7138, device='cuda:0', grad_fn=<MulBackward0>)
# 0.93% del epoch 3
# Perdida de wavenet:
# tensor(1.9188, device='cuda:0', grad_fn=<AddBackward0>)
#
# tensor(0.0417, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(0.9296, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(0.9475, device='cuda:0', grad_fn=<MulBackward0>)
# 1.03% del epoch 3
# Perdida de wavenet:
# tensor(1.7906, device='cuda:0', grad_fn=<AddBackward0>)
#
# tensor(0.0578, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(0.8969, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(0.8359, device='cuda:0', grad_fn=<MulBackward0>)
# 1.13% del epoch 3
# Perdida de wavenet:
# tensor(1.8399, device='cuda:0', grad_fn=<AddBackward0>)
#
# tensor(0.0621, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(0.9878, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(0.7901, device='cuda:0', grad_fn=<MulBackward0>)
# 1.23% del epoch 3
# Perdida de wavenet:
# tensor(1.5342, device='cuda:0', grad_fn=<AddBackward0>)
#
# tensor(0.0447, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(0.6992, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(0.7903, device='cuda:0', grad_fn=<MulBackward0>)
# 1.34% del epoch 3
# Perdida de wavenet:
# tensor(1.6267, device='cuda:0', grad_fn=<AddBackward0>)
#
# tensor(0.0232, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(0.8030, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(0.8006, device='cuda:0', grad_fn=<MulBackward0>)
# 1.44% del epoch 3
# Perdida de wavenet:
# tensor(1.6316, device='cuda:0', grad_fn=<AddBackward0>)
#
# tensor(0.0484, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(0.9218, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(0.6614, device='cuda:0', grad_fn=<MulBackward0>)
# 1.54% del epoch 3
# Perdida de wavenet:
# tensor(1.5123, device='cuda:0', grad_fn=<AddBackward0>)
#
# tensor(0.0324, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(0.8287, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(0.6512, device='cuda:0', grad_fn=<MulBackward0>)
# 1.65% del epoch 3
# Perdida de wavenet:
# tensor(1.4156, device='cuda:0', grad_fn=<AddBackward0>)
#
# tensor(0.0302, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(0.6707, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(0.7147, device='cuda:0', grad_fn=<MulBackward0>)
# 1.75% del epoch 3
# Perdida de wavenet:
# tensor(1.6582, device='cuda:0', grad_fn=<AddBackward0>)
#
# tensor(0.0929, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(0.7820, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(0.7832, device='cuda:0', grad_fn=<MulBackward0>)
# 1.85% del epoch 3
# Perdida de wavenet:
# tensor(1.5742, device='cuda:0', grad_fn=<AddBackward0>)
#
# tensor(0.0773, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(0.7586, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(0.7383, device='cuda:0', grad_fn=<MulBackward0>)
# 1.95% del epoch 3
# Perdida de wavenet:
# tensor(1.9565, device='cuda:0', grad_fn=<AddBackward0>)
#
# tensor(0.0503, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(0.9953, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(0.9109, device='cuda:0', grad_fn=<MulBackward0>)
# 2.06% del epoch 3
# Perdida de wavenet:
# tensor(1.8752, device='cuda:0', grad_fn=<AddBackward0>)
#
# tensor(0.0896, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(0.8405, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(0.9451, device='cuda:0', grad_fn=<MulBackward0>)
# 2.16% del epoch 3
# Perdida de wavenet:
# tensor(1.7541, device='cuda:0', grad_fn=<AddBackward0>)
#
# tensor(0.0492, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(0.8503, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(0.8546, device='cuda:0', grad_fn=<MulBackward0>)
# 2.26% del epoch 3
# Perdida de wavenet:
# tensor(1.5375, device='cuda:0', grad_fn=<AddBackward0>)
#
# tensor(0.0358, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(0.7583, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(0.7434, device='cuda:0', grad_fn=<MulBackward0>)
# 2.37% del epoch 3
# Perdida de wavenet:
# tensor(1.5287, device='cuda:0', grad_fn=<AddBackward0>)
#
# tensor(0.0586, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(0.7588, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(0.7114, device='cuda:0', grad_fn=<MulBackward0>)
# 2.47% del epoch 3
# Perdida de wavenet:
# tensor(1.2470, device='cuda:0', grad_fn=<AddBackward0>)
#
# tensor(0.0435, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(0.6710, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(0.5325, device='cuda:0', grad_fn=<MulBackward0>)
# 2.57% del epoch 3
# Perdida de wavenet:
# tensor(1.8409, device='cuda:0', grad_fn=<AddBackward0>)
#
# tensor(0.0562, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(0.9373, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(0.8474, device='cuda:0', grad_fn=<MulBackward0>)
# 2.67% del epoch 3
# Perdida de wavenet:
# tensor(1.7987, device='cuda:0', grad_fn=<AddBackward0>)
#
# tensor(0.0665, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(0.8966, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(0.8356, device='cuda:0', grad_fn=<MulBackward0>)
# 2.78% del epoch 3
# Perdida de wavenet:
# tensor(1.5681, device='cuda:0', grad_fn=<AddBackward0>)
#
# tensor(0.0682, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(0.8643, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(0.6356, device='cuda:0', grad_fn=<MulBackward0>)
# 2.88% del epoch 3
# Perdida de wavenet:
# tensor(1.3685, device='cuda:0', grad_fn=<AddBackward0>)
#
# tensor(0.0458, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(0.6507, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(0.6720, device='cuda:0', grad_fn=<MulBackward0>)
# 2.98% del epoch 3
# Perdida de wavenet:
# tensor(1.4246, device='cuda:0', grad_fn=<AddBackward0>)
#
# tensor(0.0547, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(0.6609, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(0.7090, device='cuda:0', grad_fn=<MulBackward0>)
# 3.09% del epoch 3
# Perdida de wavenet:
# tensor(1.3874, device='cuda:0', grad_fn=<AddBackward0>)
#
# tensor(0.0469, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(0.6650, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(0.6754, device='cuda:0', grad_fn=<MulBackward0>)
# 3.19% del epoch 3
# Perdida de wavenet:
# tensor(2.1012, device='cuda:0', grad_fn=<AddBackward0>)
#
# tensor(0.0730, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(1.0592, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(0.9691, device='cuda:0', grad_fn=<MulBackward0>)
# 3.29% del epoch 3
# Perdida de wavenet:
# tensor(1.6151, device='cuda:0', grad_fn=<AddBackward0>)
#
# tensor(0.0547, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(0.7715, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(0.7889, device='cuda:0', grad_fn=<MulBackward0>)
# 3.39% del epoch 3
# Perdida de wavenet:
# tensor(1.7050, device='cuda:0', grad_fn=<AddBackward0>)
#
# tensor(0.0497, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(0.9985, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(0.6568, device='cuda:0', grad_fn=<MulBackward0>)
# 3.5% del epoch 3
# Perdida de wavenet:
# tensor(1.7525, device='cuda:0', grad_fn=<AddBackward0>)
#
# tensor(0.0420, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(0.8841, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(0.8264, device='cuda:0', grad_fn=<MulBackward0>)
# 3.6% del epoch 3
# Perdida de wavenet:
# tensor(1.4901, device='cuda:0', grad_fn=<AddBackward0>)
#
# tensor(0.0901, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(0.7666, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(0.6334, device='cuda:0', grad_fn=<MulBackward0>)
# 3.7% del epoch 3
# Perdida de wavenet:
# tensor(1.6460, device='cuda:0', grad_fn=<AddBackward0>)
#
# tensor(0.0749, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(0.7841, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(0.7870, device='cuda:0', grad_fn=<MulBackward0>)
# 3.81% del epoch 3
# Perdida de wavenet:
# tensor(1.7590, device='cuda:0', grad_fn=<AddBackward0>)
#
# tensor(0.0297, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(0.9295, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(0.7997, device='cuda:0', grad_fn=<MulBackward0>)
# 3.91% del epoch 3
# Perdida de wavenet:
# tensor(1.7388, device='cuda:0', grad_fn=<AddBackward0>)
#
# tensor(0.0461, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(0.8863, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(0.8063, device='cuda:0', grad_fn=<MulBackward0>)
# 4.01% del epoch 3
# Perdida de wavenet:
# tensor(1.5000, device='cuda:0', grad_fn=<AddBackward0>)
#
# tensor(0.0653, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(0.7083, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(0.7264, device='cuda:0', grad_fn=<MulBackward0>)
# 4.11% del epoch 3
# Perdida de wavenet:
# tensor(1.3201, device='cuda:0', grad_fn=<AddBackward0>)
#
# tensor(0.0561, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(0.6130, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(0.6509, device='cuda:0', grad_fn=<MulBackward0>)
# 4.22% del epoch 3
# Perdida de wavenet:
# tensor(1.4975, device='cuda:0', grad_fn=<AddBackward0>)
#
# tensor(0.0548, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(0.7462, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(0.6965, device='cuda:0', grad_fn=<MulBackward0>)
# 4.32% del epoch 3
# Perdida de wavenet:
# tensor(1.4578, device='cuda:0', grad_fn=<AddBackward0>)
#
# tensor(0.0302, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(0.7140, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(0.7136, device='cuda:0', grad_fn=<MulBackward0>)
# 4.42% del epoch 3
# Perdida de wavenet:
# tensor(1.8033, device='cuda:0', grad_fn=<AddBackward0>)
#
# tensor(0.0312, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(0.9077, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(0.8645, device='cuda:0', grad_fn=<MulBackward0>)
# 4.53% del epoch 3
# Perdida de wavenet:
# tensor(1.7620, device='cuda:0', grad_fn=<AddBackward0>)
#
# tensor(0.0726, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(0.8235, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(0.8660, device='cuda:0', grad_fn=<MulBackward0>)
# 4.63% del epoch 3
# Perdida de wavenet:
# tensor(1.9163, device='cuda:0', grad_fn=<AddBackward0>)
#
# tensor(0.0581, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(0.9656, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(0.8926, device='cuda:0', grad_fn=<MulBackward0>)
# 4.73% del epoch 3
# Perdida de wavenet:
# tensor(1.6661, device='cuda:0', grad_fn=<AddBackward0>)
#
# tensor(0.0813, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(0.8863, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(0.6985, device='cuda:0', grad_fn=<MulBackward0>)
# 0.0% del epoch 4
# Perdida de wavenet:
# tensor(1.8601, device='cuda:0', grad_fn=<AddBackward0>)
#
# tensor(0.0625, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(0.9559, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(0.8417, device='cuda:0', grad_fn=<MulBackward0>)
# 0.1% del epoch 4
# Perdida de wavenet:
# tensor(1.5029, device='cuda:0', grad_fn=<AddBackward0>)
#
# tensor(0.0559, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(0.7374, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(0.7096, device='cuda:0', grad_fn=<MulBackward0>)
# 0.21% del epoch 4
# Perdida de wavenet:
# tensor(1.6839, device='cuda:0', grad_fn=<AddBackward0>)
#
# tensor(0.0420, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(0.8745, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(0.7673, device='cuda:0', grad_fn=<MulBackward0>)
# 0.31% del epoch 4
# Perdida de wavenet:
# tensor(2.0750, device='cuda:0', grad_fn=<AddBackward0>)
#
# tensor(0.0862, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(1.0661, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(0.9227, device='cuda:0', grad_fn=<MulBackward0>)
# 0.41% del epoch 4
# Perdida de wavenet:
# tensor(1.7510, device='cuda:0', grad_fn=<AddBackward0>)
#
# tensor(0.0864, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(0.8650, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(0.7995, device='cuda:0', grad_fn=<MulBackward0>)
# 0.51% del epoch 4
# Perdida de wavenet:
# tensor(1.8829, device='cuda:0', grad_fn=<AddBackward0>)
#
# tensor(0.0689, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(0.9020, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(0.9120, device='cuda:0', grad_fn=<MulBackward0>)
# 0.62% del epoch 4
# Perdida de wavenet:
# tensor(1.5645, device='cuda:0', grad_fn=<AddBackward0>)
#
# tensor(0.0658, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(0.6979, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(0.8008, device='cuda:0', grad_fn=<MulBackward0>)
# 0.72% del epoch 4
# Perdida de wavenet:
# tensor(1.8828, device='cuda:0', grad_fn=<AddBackward0>)
#
# tensor(0.0546, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(1.0327, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(0.7955, device='cuda:0', grad_fn=<MulBackward0>)
# 0.82% del epoch 4
# Perdida de wavenet:
# tensor(1.7123, device='cuda:0', grad_fn=<AddBackward0>)
#
# tensor(0.0760, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(0.9153, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(0.7211, device='cuda:0', grad_fn=<MulBackward0>)
# 0.93% del epoch 4
# Perdida de wavenet:
# tensor(1.4581, device='cuda:0', grad_fn=<AddBackward0>)
#
# tensor(0.0419, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(0.7323, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(0.6839, device='cuda:0', grad_fn=<MulBackward0>)
# 1.03% del epoch 4
# Perdida de wavenet:
# tensor(1.1805, device='cuda:0', grad_fn=<AddBackward0>)
#
# tensor(0.0440, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(0.5651, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(0.5714, device='cuda:0', grad_fn=<MulBackward0>)
# 1.13% del epoch 4
# Perdida de wavenet:
# tensor(1.8525, device='cuda:0', grad_fn=<AddBackward0>)
#
# tensor(0.0418, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(0.9168, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(0.8939, device='cuda:0', grad_fn=<MulBackward0>)
# 1.23% del epoch 4
# Perdida de wavenet:
# tensor(1.7798, device='cuda:0', grad_fn=<AddBackward0>)
#
# tensor(0.0480, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(0.8947, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(0.8371, device='cuda:0', grad_fn=<MulBackward0>)
# 1.34% del epoch 4
# Perdida de wavenet:
# tensor(1.4523, device='cuda:0', grad_fn=<AddBackward0>)
#
# tensor(0.0571, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(0.8016, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(0.5936, device='cuda:0', grad_fn=<MulBackward0>)
# 1.44% del epoch 4
# Perdida de wavenet:
# tensor(1.5810, device='cuda:0', grad_fn=<AddBackward0>)
#
# tensor(0.0526, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(0.8313, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(0.6971, device='cuda:0', grad_fn=<MulBackward0>)
# 1.54% del epoch 4
# Perdida de wavenet:
# tensor(1.8023, device='cuda:0', grad_fn=<AddBackward0>)
#
# tensor(0.0693, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(0.8273, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(0.9057, device='cuda:0', grad_fn=<MulBackward0>)
# 1.65% del epoch 4
# Perdida de wavenet:
# tensor(1.8486, device='cuda:0', grad_fn=<AddBackward0>)
#
# tensor(0.0552, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(1.0393, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(0.7541, device='cuda:0', grad_fn=<MulBackward0>)
# 1.75% del epoch 4
# Perdida de wavenet:
# tensor(1.5861, device='cuda:0', grad_fn=<AddBackward0>)
#
# tensor(0.0394, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(0.7881, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(0.7587, device='cuda:0', grad_fn=<MulBackward0>)
# 1.85% del epoch 4
# Perdida de wavenet:
# tensor(1.4148, device='cuda:0', grad_fn=<AddBackward0>)
#
# tensor(0.0679, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(0.6876, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(0.6592, device='cuda:0', grad_fn=<MulBackward0>)
# 1.95% del epoch 4
# Perdida de wavenet:
# tensor(1.9321, device='cuda:0', grad_fn=<AddBackward0>)
#
# tensor(0.0761, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(0.8294, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(1.0266, device='cuda:0', grad_fn=<MulBackward0>)
# 2.06% del epoch 4
# Perdida de wavenet:
# tensor(1.9232, device='cuda:0', grad_fn=<AddBackward0>)
#
# tensor(0.0384, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(0.9631, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(0.9217, device='cuda:0', grad_fn=<MulBackward0>)
# 2.16% del epoch 4
# Perdida de wavenet:
# tensor(1.3939, device='cuda:0', grad_fn=<AddBackward0>)
#
# tensor(0.0572, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(0.6684, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(0.6683, device='cuda:0', grad_fn=<MulBackward0>)
# 2.26% del epoch 4
# Perdida de wavenet:
# tensor(1.4405, device='cuda:0', grad_fn=<AddBackward0>)
#
# tensor(0.0450, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(0.6578, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(0.7377, device='cuda:0', grad_fn=<MulBackward0>)
# 2.37% del epoch 4
# Perdida de wavenet:
# tensor(1.7697, device='cuda:0', grad_fn=<AddBackward0>)
#
# tensor(0.0615, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(0.8629, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(0.8453, device='cuda:0', grad_fn=<MulBackward0>)
# 2.47% del epoch 4
# Perdida de wavenet:
# tensor(2.2237, device='cuda:0', grad_fn=<AddBackward0>)
#
# tensor(0.0645, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(1.1707, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(0.9885, device='cuda:0', grad_fn=<MulBackward0>)
# 2.57% del epoch 4
# Perdida de wavenet:
# tensor(1.4830, device='cuda:0', grad_fn=<AddBackward0>)
#
# tensor(0.0328, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(0.7788, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(0.6714, device='cuda:0', grad_fn=<MulBackward0>)
# 2.67% del epoch 4
# Perdida de wavenet:
# tensor(1.6041, device='cuda:0', grad_fn=<AddBackward0>)
#
# tensor(0.0661, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(0.7791, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(0.7589, device='cuda:0', grad_fn=<MulBackward0>)
# 2.78% del epoch 4
# Perdida de wavenet:
# tensor(1.8852, device='cuda:0', grad_fn=<AddBackward0>)
#
# tensor(0.0615, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(0.9321, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(0.8916, device='cuda:0', grad_fn=<MulBackward0>)
# 2.88% del epoch 4
# Perdida de wavenet:
# tensor(1.4960, device='cuda:0', grad_fn=<AddBackward0>)
#
# tensor(0.0375, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(0.7657, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(0.6928, device='cuda:0', grad_fn=<MulBackward0>)
# 2.98% del epoch 4
# Perdida de wavenet:
# tensor(1.4250, device='cuda:0', grad_fn=<AddBackward0>)
#
# tensor(0.0441, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(0.7002, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(0.6807, device='cuda:0', grad_fn=<MulBackward0>)
# 3.09% del epoch 4
# Perdida de wavenet:
# tensor(1.3988, device='cuda:0', grad_fn=<AddBackward0>)
#
# tensor(0.0686, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(0.6556, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(0.6746, device='cuda:0', grad_fn=<MulBackward0>)
# 3.19% del epoch 4
# Perdida de wavenet:
# tensor(1.6845, device='cuda:0', grad_fn=<AddBackward0>)
#
# tensor(0.0647, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(0.9048, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(0.7151, device='cuda:0', grad_fn=<MulBackward0>)
# 3.29% del epoch 4
# Perdida de wavenet:
# tensor(1.9433, device='cuda:0', grad_fn=<AddBackward0>)
#
# tensor(0.0311, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(1.0208, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(0.8914, device='cuda:0', grad_fn=<MulBackward0>)
# 3.39% del epoch 4
# Perdida de wavenet:
# tensor(1.5837, device='cuda:0', grad_fn=<AddBackward0>)
#
# tensor(0.0822, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(0.7513, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(0.7502, device='cuda:0', grad_fn=<MulBackward0>)
# 3.5% del epoch 4
# Perdida de wavenet:
# tensor(1.4869, device='cuda:0', grad_fn=<AddBackward0>)
#
# tensor(0.0572, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(0.7822, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(0.6475, device='cuda:0', grad_fn=<MulBackward0>)
# 3.6% del epoch 4
# Perdida de wavenet:
# tensor(2.2434, device='cuda:0', grad_fn=<AddBackward0>)
#
# tensor(0.0920, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(1.1013, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(1.0501, device='cuda:0', grad_fn=<MulBackward0>)
# 3.7% del epoch 4
# Perdida de wavenet:
# tensor(1.0424, device='cuda:0', grad_fn=<AddBackward0>)
#
# tensor(0.0438, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(0.4802, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(0.5184, device='cuda:0', grad_fn=<MulBackward0>)
# 3.81% del epoch 4
# Perdida de wavenet:
# tensor(1.3560, device='cuda:0', grad_fn=<AddBackward0>)
#
# tensor(0.0291, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(0.6627, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(0.6641, device='cuda:0', grad_fn=<MulBackward0>)
# 3.91% del epoch 4
# Perdida de wavenet:
# tensor(1.3334, device='cuda:0', grad_fn=<AddBackward0>)
#
# tensor(0.0445, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(0.6762, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(0.6127, device='cuda:0', grad_fn=<MulBackward0>)
# 4.01% del epoch 4
# Perdida de wavenet:
# tensor(1.2514, device='cuda:0', grad_fn=<AddBackward0>)
#
# tensor(0.0663, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(0.6500, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(0.5350, device='cuda:0', grad_fn=<MulBackward0>)
# 4.11% del epoch 4
# Perdida de wavenet:
# tensor(2.0627, device='cuda:0', grad_fn=<AddBackward0>)
#
# tensor(0.0472, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(1.1119, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(0.9036, device='cuda:0', grad_fn=<MulBackward0>)
# 4.22% del epoch 4
# Perdida de wavenet:
# tensor(2.1707, device='cuda:0', grad_fn=<AddBackward0>)
#
# tensor(0.0464, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(1.1220, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(1.0023, device='cuda:0', grad_fn=<MulBackward0>)
# 4.32% del epoch 4
# Perdida de wavenet:
# tensor(1.5500, device='cuda:0', grad_fn=<AddBackward0>)
#
# tensor(0.0588, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(0.7597, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(0.7315, device='cuda:0', grad_fn=<MulBackward0>)
# 4.42% del epoch 4
# Perdida de wavenet:
# tensor(1.8509, device='cuda:0', grad_fn=<AddBackward0>)
#
# tensor(0.0389, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(1.1060, device='cuda:0', grad_fn=<MulBackward0>)
# tensor(0.7060, device='cuda:0', grad_fn=<MulBackward0>)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[26], line 26
#      23 optimizer.step()
#      24 #optimizerPost.step()
# ---> 26 avgLossOfBatch.append(loss.item())
#      27 xs = 2917 * epoch + i
#      28 writer.add_scalar("Loss audio", lossAudio, xs)
#
# KeyboardInterrupt:

# %%
torch.save(wavenetModel.state_dict(), modeloNombre)

# %%
13 % 1==0

# %%
writer.close()

# %%
#predicho = wavenetModel(X).detach().to("cuda")
X = X.to("cuda")
true_y = true_y.to("cuda")

# %%
wdet = wavenetModel(X).detach()
predicho = wdet.cpu()
X = X.cpu()
true_y = true_y.cpu()

# %%
opin = [1,2,4,5,6,7]

# %%
audioAnalizar = 0

# %%
lossSpect1, lossSpect2 = melspectogramLoss(predicho[audioAnalizar], true_y[audioAnalizar])
loss1 = loss_fn(predicho[audioAnalizar], true_y[audioAnalizar])
loss = loss1 + lossSpect1 + lossSpect2
print("error de prediccion " + str(loss.item()))


lossSpect1t, lossSpect2t = melspectogramLoss(X[audioAnalizar], true_y[audioAnalizar])
loss2 = loss_fn(X[audioAnalizar], true_y[audioAnalizar])
loss2t = loss2 + lossSpect1t + lossSpect2t

print("error sin hacer nada " + str(loss2t.item()))

# %%
Audio(data=X.cpu()[audioAnalizar], rate=16000)

# %%
Audio(data=predicho.cpu()[audioAnalizar], rate=16000)

# %%
Audio(data=predichoPost.cpu()[audioAnalizar], rate=16000)

# %%
Audio(data=true_y.cpu()[audioAnalizar], rate=16000)

# %%
audioAnalizar = 1

# %%
pos = 4200
delta = 2000
onda = predicho[audioAnalizar][0][pos:pos+delta]
onda2 = true_y[audioAnalizar][0][pos:pos+delta]
#onda3 = X[audioAnalizar][0][pos:pos+delta]

sns.lineplot(x=range(0,len(onda2)), y=(onda2), label="Real")
#sns.lineplot(x=range(0,len(onda3)), y=(onda3), label="Sucia")
sns.lineplot(x=range(0,len(onda)), y=(onda), label="Predicha")

# %%
  mel1true_y = mel_transform1(true_y.to('cuda'))
  mel1y_pred = mel_transform1(predicho.to('cuda'))
  mel1sucio = mel_transform1(X.to('cuda'))

# %%
mel_spectrogram_db = transformsaudio.AmplitudeToDB()(mel1true_y).cpu()


# Display the mel spectrogram
plt.figure(figsize=(10, 4))
plt.imshow(mel_spectrogram_db[0][0].detach().numpy(), cmap='viridis', origin='lower', aspect='auto')
plt.colorbar(format="%+2.0f dB")
plt.title("Mel Spectrogram verdadero")
plt.xlabel("Time")
plt.ylabel("Mel Frequency Bin")
plt.show()

# %%
mel_spectrogram_db2 = transformsaudio.AmplitudeToDB()(mel1y_pred).cpu()


# Display the mel spectrogram
plt.figure(figsize=(10, 4))
plt.imshow(mel_spectrogram_db2[0][0].detach().numpy(), cmap='viridis', origin='lower', aspect='auto')
plt.colorbar(format="%+2.0f dB")
plt.title("Mel Spectrogram predicho")
plt.xlabel("Time")
plt.ylabel("Mel Frequency Bin")
plt.show()

# %%
mel_spectrogram_db3 = transformsaudio.AmplitudeToDB()(mel1sucio).cpu()


# Display the mel spectrogram
plt.figure(figsize=(10, 4))
plt.imshow(mel_spectrogram_db3[0][0].detach().numpy(), cmap='viridis', origin='lower', aspect='auto')
plt.colorbar(format="%+2.0f dB")
plt.title("Mel Spectrogram sucio")
plt.xlabel("Time")
plt.ylabel("Mel Frequency Bin")
plt.show()

# %%
audioAnalizar = 0

# %%
import soundfile as sf

# %%
for audioAnalizar in opin:
  sf.write('sucio'+str(audioAnalizar)+'.wav', np.ravel(X[audioAnalizar]), 16000, 'PCM_24')
  sf.write('original'+str(audioAnalizar)+'.wav', np.ravel(true_y[audioAnalizar]), 16000, 'PCM_24')
  sf.write('limpiado'+str(audioAnalizar)+'.wav', np.ravel(predicho[audioAnalizar][0]), 16000, 'PCM_24')

# %%
sf.write('sucio'+str(audioAnalizar)+'.wav', np.ravel(X[audioAnalizar]), 16000, 'PCM_24')

# %%
sf.write('limpiadoEco'+str(audioAnalizar)+'.wav', np.ravel(predicho[audioAnalizar][0]), 16000, 'PCM_24')

# %%
sf.write('originalSinTocarWavenetReplica'+str(audioAnalizar)+'.wav', np.ravel(true_y[audioAnalizar]), 16000, 'PCM_24')

# %%
#dataloader give 1 example
ini = time.time()
for waveform, label in dataloader:
    print(waveform.shape)
    print(label.shape)
    break
fin = time.time()

# %%
out = modelPanoramico(waveform)

# %%
nuevow = WaveNet( layer_size=18, stack_size=2, in_channels=1, res_channels=128)

# %%
#nuevow.load_state_dict(torch.load(modeloNombre), map_location=torch.device('cpu'))
nuevow = torch.load(modeloNombre, map_location=torch.device('cpu'))

# %%
predicho = nuevow(waveform).detach().cpu()
waveform = waveform.cpu().detach()
true_y = label.cpu()
X = waveform

# %%
lossSpect1, lossSpect2 = melspectogramLoss(predicho[audioAnalizar], true_y[audioAnalizar])
loss1 = loss_fn(predicho[audioAnalizar], true_y[audioAnalizar])
loss = loss1 + lossSpect1 + lossSpect2
print("error de prediccion " + str(loss.item()))

lossSpect1t, lossSpect2t = melspectogramLoss(waveform[audioAnalizar], true_y[audioAnalizar])
loss2 = loss_fn(waveform[audioAnalizar], true_y[audioAnalizar])
loss2t = loss2 + lossSpect1t + lossSpect2t

print("error sin hacer nada " + str(loss2t.item()))

# %%
class WaveNetPanoramico(pl.LightningModule):
    def __init__(self, layer_size, stack_size, in_channels, res_channels):
        """
        Stack residual blocks by layer and stack size
        :param layer_size: integer, 10 = layer[dilation=1, dilation=2, 4, 8, 16, 32, 64, 128, 256, 512]
        :param stack_size: integer, 5 = stack[layer1, layer2, layer3, layer4, layer5]
        :param in_channels: number of channels for input data. skip channel is same as input channel
        :param res_channels: number of residual channel for input, output
        :return:
        """
        super(WaveNetPanoramico, self).__init__()

        self.receptive_fields = self.calc_receptive_fields(layer_size, stack_size)

        self.causal = CausalConv1d(in_channels, res_channels)

        self.res_stack = ResidualStack(layer_size, stack_size, res_channels, in_channels)

        self.densnet = DensNet(in_channels)

        self.loss_fun = nn.MSELoss()
        inp = layer_size*stack_size+res_channels+1
        inp2 = math.floor(inp/2)
        self.convFinal1 = nn.Conv1d(in_channels=layer_size*stack_size+res_channels+1,
                                   out_channels=inp2,
                                   kernel_size=15, stride=1,
                                   dilation=1, padding=7, bias=True).to("cuda")
        self.convFinal2 = nn.Conv1d(in_channels=inp2,
                                   out_channels=1,
                                   kernel_size=15, stride=1,
                                   dilation=1, padding=7, bias=True).to("cuda")

        self.convFinal3 = nn.Conv1d(in_channels=1,
                                   out_channels=1,
                                   kernel_size=101, stride=1,
                                   dilation=1, padding=50, bias=False).to("cuda")


        self.relu = nn.ReLU()

    @staticmethod
    def calc_receptive_fields(layer_size, stack_size):
        layers = [2 ** i for i in range(0, layer_size)] * stack_size
        num_receptive_fields = np.sum(layers)

        return int(num_receptive_fields)

    def calc_output_size(self, x):
        output_size = int(x.size(2)) - self.receptive_fields

        #self.check_input_size(x, output_size)

        return inputSize

    def check_input_size(self, x, output_size):
        if output_size < 1:
            raise InputSizeError(int(x.size(2)), self.receptive_fields, output_size)

    def forward(self, x):
        """
        The size of timestep(3rd dimention) has to be bigger than receptive fields
        :param x: Tensor[batch, timestep, channels]
        :return: Tensor[batch, timestep, channels]
        """
        output = x#.transpose(1, 2)
        copiaConvolucionFinal = x.clone()

        output_size = self.calc_output_size(output)

        output = self.causal(output)

        skip_connections = self.res_stack(output, output_size)



        #en vez de sumar skip connections hago convolucion
        #print(skip_connections.shape)
        #output = torch.sum(skip_connections, dim=0)
        skip_connections_squeezed = skip_connections.squeeze()
        # Check the shape
        # Swap the first two dimensions
        skip_connections_squeezed = skip_connections_squeezed.transpose(0, 1)
        output = torch.cat((output, copiaConvolucionFinal), dim=1)

        output = torch.cat((output, skip_connections_squeezed), dim=1)

        output = self.convFinal1(output)
        output = self.relu(output)
        output = self.convFinal2(output)
        #output = self.relu(output)
        #output = self.convFinal3(output)

        #output = self.densnet(output)

        return output#.transpose(1, 2).contiguous()

# %%
class PostNetSimple(pl.LightningModule):
  def __init__(self, layers=12):
    super(PostNetSimple, self).__init__()
    self.convInicial = nn.Conv1d(in_channels=1,
                            out_channels=128,
                            kernel_size=33, stride=1,
                            dilation=1, padding=16, bias=True).to("cuda")
    self.totalLayers = layers
    self.convs = []
    for conv in range(0, layers):
      self.convs.append(
          nn.Conv1d(in_channels=128,
                            out_channels=128,
                            kernel_size=33, stride=1,
                            dilation=1, padding=16, bias=True).to("cuda")
      )
    self.convFinal = nn.Conv1d(in_channels=129,
                            out_channels=1,
                            kernel_size=33, stride=1,
                            dilation=1, padding=16, bias=True).to("cuda")
    self.tan = nn.Tanh()

  def forward(self, x):
    xCopia = x.clone()
    x = self.convInicial(x)
    x = self.tan(x)
    for conv in self.convs:
      x = conv(x)
      x = self.tan(x)
    x = torch.cat((x, xCopia), dim=1)
    x = self.convFinal(x)
    return x
